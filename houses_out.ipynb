# %% [markdown]
# # Модель выбытия жилищного фонда

# %%
import requests
from cmasf import pandas_sql as pds
import pandas as pd
import sqlalchemy as sa
import re
from os import path, remove
import glob
from bs4 import BeautifulSoup
import datetime as dt

strDB_Temp=path.join('DB', 'Temp') # путь к папке с временными файлами
strBaseDB_URL=r'https://www.reformagkh.ru/opendata?gid=2208161&cids=house_management&page={page_num}&pageSize={page_size}'

strExportDataURL=r'https://www.reformagkh.ru/opendata/export/{num}'

# %% [markdown]
# ## База данных - сбор
#
# <p>Источник данных - https://www.reformagkh.ru/opendata?gid=2208161&cids=house_management&page=1&pageSize=100</p>
# <p>Качаем паспорта домов из <b>"Реестра домов"</b> по каждому региону</i> </p>
#
# <div class="alert alert-block alert-info">
# <p>Условие попадания дома в расчеты модели: </p>
#     <ul>
#         <li>ненулевые данные об общей площади жилых помещений <b>(living_rooms_sq > 0)</b></li>
#         <li>ненулевое количество жилых помещений <b>(living_rooms_amount > 0)</b></li>
#         <li>соотношение этих параметров находилось в интервале между 3 и 1000 <b>(3 < living_rooms_sq/living_rooms_amount < 1000 )</b></li>
#     </ul>
# </div>
#
# <div class="alert alert-block alert-success">
# <p><b>Поля, используемые в расчетах:</b></p>
#      <ol>
#          <li>Возраст здания <b>(текущий год - commission_year)</b></li>
#          <li>Этажность</li>
#       </ul>
# </div>

# %%
re_p_cap_class=re.compile('lh-27 f-18 fw-700') # объект для поиска заголовка строки, например, "...по Алтайскому краю"
# re_p_cap_text=re.compile(r'отчет КР 1\.1') # объект для поиска признака "Капитальный ремонт", это не очень нужно, т.к. данные читаются из соотв. раздела
re_a_export=re.compile(r'/opendata/export/\d+') # объект для поиска признака ссылки на файл csv
re_p_date=re.compile('Актуальная версия:') # объект для поиска даты актиализации

re_cap=re.compile('\sдомов по([А-Яа-я -]+)') # объект для поиска части заголовка - "по Алтайскому краю" - для идентификации ссылки на файл
re_a_num=re.compile('\d+$') # объект для поиска номера (кода, НЕ соотв. коду региона) файла csv
re_date=re.compile('\d{2}\.\d{2}\.\d{4}') # объект для поиска захвата даты актуализации

re_pass_dt=re.compile('p-5 mx-4') # объект для поиска куска с паспортом набора даных

def delete_temp_files(folder=strDB_Temp):
    """Удаление файлов во временой папке - ОСТОРОЖНО!!! УДАЛЯЕТ ВСЕ ФАЙЛЫ В УКАЗАННОЙ ПАПКЕ!!!
    Вызывать для очистки папки временных файлов после обновления базы данных"""
    files = glob.glob(path.join(folder, '*.zip'))
    for f in files:
        remove(f)

def read_data_password():
    """Вспомогательная функция - чтение паспорта набора данных
    читаем структуру данных в файлах csv - считаем, что она одинакова для всех наборов, поэтому читаем и парсим только
    первую. Структура нужна для расшифровки названия полей в файлах и выборки необходимых для модели"""
    rgkh_html=requests.get(strBaseDB_URL.format(page_num=1, page_size=10)) # читаем только первую страницу
    gkh_soup=BeautifulSoup(rgkh_html.text, 'html.parser')
    
    omg=gkh_soup.find('p', {'class':re_p_cap_class}, text=re_cap)
    div_pass=omg.find_next('div', class_=re_pass_dt)
    dv_rows=div_pass.findAll('div', class_='row')

    dct_pass=dict()
    for row in dv_rows:
        dv=row.findAll('div')
        dct_pass.setdefault(dv[0].text, dv[1].text)
    return dct_pass

read_data_password()
print(read_data_password())

# lst_neede_fileds=['subject_rf', 'mun_obr_oktmo', 'mun_obr',  'houseguid', 'address', 'commission_year', 'total_sq', ]
# Out:
# {'id': 'ID дома на Портале', 'region_id': 'Субъект РФ (код ФИАС)', 'area_id': 'Район (код ФИАС)', 'city_id': 'Населенный пункт (код ФИАС)', 'street_id': 'Улица (код ФИАС)', 'shortname_region': 'Тип Субъекта РФ', 'formalname_region': 'Субъект РФ (наименование)', 'shortname_area': 'Тип района', 'formalname_area': 'Район (наименование)', 'shortname_city': 'Тип населенного пункта', 'formalname_city': 'Населенный пункт (наименование)', 'shortname_street': 'Тип улицы', 'formalname_street': 'Улица (наименование)', 'house_number': 'Номер дома', 'building': 'Строение', 'block': 'Корпус', 'letter': 'Литера', 'address': 'Адрес дома', 'houseguid': 'Глобальный уникальный идентификатор дома', 'management_organization_id': 'ID Управляющей организации на Портале', 'built_year': 'Год постройки', 'exploitation_start_year': 'Год ввода в эксплуатацию', 'project_type': 'Серия, тип постройки здания', 'house_type': 'Тип дома', 'is_alarm': 'Факт признания дома аварийным', 'method_of_forming_overhaul_fund': 'Способ формирования фонда капитального ремонта', 'floor_count_max': 'Наибольшее количество этажей, ед.', 'floor_count_min': 'Наименьшее количество этажей, ед.', 'entrance_count': 'Количество подъездов, ед.', 'elevators_count': 'Количество лифтов, ед.', 'energy_efficiency': 'Класс энергетической эффективности', 'quarters_count': 'Количество помещений, всего, ед.', 'living_quarters_count': 'Количество жилых помещений, ед.', 'unliving_quarters_count': 'Количество нежилых помещений, ед.', 'area_total': 'Общая площадь дома, всего, кв.м', 'area_residential': 'Общая площадь жилых помещений, кв.м', 'area_non_residential': 'Общая площадь нежилых помещений, кв.м', 'area_common_property': 'Общая площадь помещений, входящих в состав общего имущества, кв.м', 'area_land': 'Площадь земельного участка, входящего в состав общего имущества в многоквартирном доме, кв.м', 'parking_square': 'Площадь парковки в границах земельного участка, кв.м', 'playground': 'Элементы благоустройства (детская площадка)', 'sportsground': 'Элементы благоустройства (спортивная площадка)', 'other_beautification': 'Элементы благоустройства (другое)', 'foundation_type': 'Тип фундамента', 'floor_type': 'Тип перекрытий', 'wall_material': 'Материал несущих стен', 'basement_area': 'Площадь подвала по полу, кв.м', 'chute_type': 'Тип мусоропровода', 'chute_count': 'Количество мусоропроводов, ед.', 'electrical_type': 'Тип системы электроснабжения', 'electrical_entries_count': 'Количество вводов в МКД, ед.', 'heating_type': 'Тип системы теплоснабжения', 'hot_water_type': 'Тип системы горячего водоснабжения', 'cold_water_type': 'Тип системы холодного водоснабжения', 'sewerage_type': 'Тип системы водоотведения', 'sewerage_cesspools_volume': 'Объем выгребных ям, куб.м', 'gas_type': 'Тип системы газоснабжения', 'ventilation_type': 'Тип системы вентиляции', 'firefighting_type': 'Тип системы пожаротушения', 'drainage_type': 'Тип системы водостоков'}

# %%
dctCodeReg=dict()
for o in gkh_soup.findAll('option', {'value':True}):
    dctCodeReg[o['value']]=o.text
# print(dctCodeReg)

# %%
# dctCodeReg={o['value']:o.text for o in gkh_soup.findAll('option', {'value':True})}

lst_source=list()

def read_page(page_num=1, page_size=100):
    def parse_row(row):
        a=row.find_all_next('a', {'href':re_a_export}, recursive=False, limit=1)[0]
        pd=row.find_all_next('p', text=re_p_date, recursive=False, limit=1)[0]
        return {'name': re_cap.search(row.text).group(0).strip(), 
                'num': re_a_num.search(a['href']).group(0), 
                'date': dt.datetime.strptime(re_date.search(pd.text).group(0), '%d.%m.%Y') }
    
    rgkh_html=requests.get(strBaseDB_URL.format(page_num=page_num, page_size=page_size))
    gkh_soup=BeautifulSoup(rgkh_html.text, 'html.parser')
    
    rows=[p for p in gkh_soup.findAll('p', {'class':re_p_cap_class}, text=re_cap)]
    if rows:
        lst_source=[parse_row(r) for r in rows]
        return pd.DataFrame(lst_source)
    else:
        return None
for i in range(1, 10):
    dtf=read_page(page_num=i)
    if dtf is not None: 
        lst_source.append(dtf)
    else:
        break
        
pdf=pd.concat(lst_source, ignore_index=True)
pdf
# Out:
#                                            name  num       date
# 0                      домов по Алтайскому краю  118 2020-07-01
# 1                     домов по Амурской области  167 2020-07-01
# 2                домов по Архангельской области  171 2020-07-01
# 3                 домов по Астраханской области   91 2020-07-01
# 4                 домов по Белгородской области  170 2020-07-01
# ..                                          ...  ...        ...
# 80                домов по Чеченской Республике   94 2020-07-01
# 81                домов по Чувашской Республике   93 2020-07-01
# 82       домов по Чукотскому автономному округу   92 2020-07-01
# 83  домов по Ямало-Ненецкому автономному округу  106 2020-07-01
# 84                 домов по Ярославской области   95 2020-07-01
#
# [85 rows x 3 columns]

# %%
for k, v in pdf.iterrows():
    print('read for ', v['name'], strExportDataURL.format(num=v.num), end='...')
    r = requests.get(strExportDataURL.format(num=v.num))
    with open(path.join(strDB_Temp, '{name}.zip'.format(name=v.num)), 'wb') as fz_tmp:
        fz_tmp.write(r.content)
    print('done')
# Out:
# read for  по Алтайскому краю https://www.reformagkh.ru/opendata/export/256...done
# read for  по Амурской области https://www.reformagkh.ru/opendata/export/255...done
# read for  по Архангельской области https://www.reformagkh.ru/opendata/export/254...done
# read for  по Астраханской области https://www.reformagkh.ru/opendata/export/253...done
# read for  по Белгородской области https://www.reformagkh.ru/opendata/export/187...done
# read for  по Брянской области https://www.reformagkh.ru/opendata/export/186...done
# read for  по Владимирской области https://www.reformagkh.ru/opendata/export/185...done
# read for  по Волгоградской области https://www.reformagkh.ru/opendata/export/252...done
# read for  по Вологодской области https://www.reformagkh.ru/opendata/export/215...done
# read for  по Воронежской области https://www.reformagkh.ru/opendata/export/251...done
# read for  по городу Москве https://www.reformagkh.ru/opendata/export/184...done
# read for  по городу Санкт-Петербургу https://www.reformagkh.ru/opendata/export/250...done
# read for  по городу Севастополю https://www.reformagkh.ru/opendata/export/249...done
# read for  по Еврейской автономной области https://www.reformagkh.ru/opendata/export/245...done
# read for  по Забайкальскому краю https://www.reformagkh.ru/opendata/export/205...done
# read for  по Ивановской области https://www.reformagkh.ru/opendata/export/183...done
# read for  по Иркутской области https://www.reformagkh.ru/opendata/export/204...done
# read for  по Кабардино-Балкарской Республике https://www.reformagkh.ru/opendata/export/244...done
# read for  по Калининградской области https://www.reformagkh.ru/opendata/export/214...done
# read for  по Калужской области https://www.reformagkh.ru/opendata/export/182...done
# read for  по Камчатскому краю https://www.reformagkh.ru/opendata/export/243...done
# read for  по Карачаево-Черкесской Республике https://www.reformagkh.ru/opendata/export/242...done
# read for  по Кемеровской области https://www.reformagkh.ru/opendata/export/203...done
# read for  по Кировской области https://www.reformagkh.ru/opendata/export/234...done
# read for  по Костромской области https://www.reformagkh.ru/opendata/export/241...done
# read for  по Краснодарскому краю https://www.reformagkh.ru/opendata/export/240...done
# read for  по Красноярскому краю https://www.reformagkh.ru/opendata/export/239...done
# read for  по Курганской области https://www.reformagkh.ru/opendata/export/191...done
# read for  по Курской области https://www.reformagkh.ru/opendata/export/181...done
# read for  по Ленинградской области https://www.reformagkh.ru/opendata/export/213...done
# read for  по Липецкой области https://www.reformagkh.ru/opendata/export/180...done
# read for  по Магаданской области https://www.reformagkh.ru/opendata/export/248...done
# read for  по Московской области https://www.reformagkh.ru/opendata/export/238...done
# read for  по Мурманской области https://www.reformagkh.ru/opendata/export/212...done
# read for  по Ненецкому автономному округу https://www.reformagkh.ru/opendata/export/211...done
# read for  по Нижегородской области https://www.reformagkh.ru/opendata/export/237...done
# read for  по Новгородской области https://www.reformagkh.ru/opendata/export/210...done
# read for  по Новосибирской области https://www.reformagkh.ru/opendata/export/202...done
# read for  по Омской области https://www.reformagkh.ru/opendata/export/201...done
# read for  по Оренбургской области https://www.reformagkh.ru/opendata/export/236...done
# read for  по Орловской области https://www.reformagkh.ru/opendata/export/179...done
# read for  по Пензенской области https://www.reformagkh.ru/opendata/export/233...done
# read for  по Пермскому краю https://www.reformagkh.ru/opendata/export/235...done
# read for  по Приморскому краю https://www.reformagkh.ru/opendata/export/228...done
# read for  по Псковской области https://www.reformagkh.ru/opendata/export/227...done
# read for  по Республике Адыгея https://www.reformagkh.ru/opendata/export/175...done
# read for  по Республике Алтай https://www.reformagkh.ru/opendata/export/226...done
# read for  по Республике Башкортостан https://www.reformagkh.ru/opendata/export/232...done
# read for  по Республике Бурятия https://www.reformagkh.ru/opendata/export/200...done
# read for  по Республике Дагестан https://www.reformagkh.ru/opendata/export/209...done
# read for  по Республике Ингушетия https://www.reformagkh.ru/opendata/export/208...done
# read for  по Республике Калмыкия https://www.reformagkh.ru/opendata/export/174...done
# read for  по Республике Карелия https://www.reformagkh.ru/opendata/export/225...done
# read for  по Республике Коми https://www.reformagkh.ru/opendata/export/224...done
# read for  по Республике Крым https://www.reformagkh.ru/opendata/export/173...done
# read for  по Республике Марий Эл https://www.reformagkh.ru/opendata/export/223...done
# read for  по Республике Мордовия https://www.reformagkh.ru/opendata/export/222...done
# read for  по Республике Саха https://www.reformagkh.ru/opendata/export/221...done
# read for  по Республике Северная Осетия-Алания https://www.reformagkh.ru/opendata/export/207...done
# read for  по Республике Татарстан https://www.reformagkh.ru/opendata/export/220...done
# read for  по Республике Тыва https://www.reformagkh.ru/opendata/export/199...done
# read for  по Республике Хакасия https://www.reformagkh.ru/opendata/export/198...done
# read for  по Ростовской области https://www.reformagkh.ru/opendata/export/219...done
# read for  по Рязанской области https://www.reformagkh.ru/opendata/export/218...done
# read for  по Самарской области https://www.reformagkh.ru/opendata/export/231...done
# read for  по Саратовской области https://www.reformagkh.ru/opendata/export/217...done
# read for  по Сахалинской области https://www.reformagkh.ru/opendata/export/216...done
# read for  по Свердловской области https://www.reformagkh.ru/opendata/export/190...done
# read for  по Смоленской области https://www.reformagkh.ru/opendata/export/178...done
# read for  по Ставропольскому краю https://www.reformagkh.ru/opendata/export/197...done
# read for  по Тамбовской области https://www.reformagkh.ru/opendata/export/196...done
# read for  по Тверской области https://www.reformagkh.ru/opendata/export/195...done
# read for  по Томской области https://www.reformagkh.ru/opendata/export/194...done
# read for  по Тульской области https://www.reformagkh.ru/opendata/export/193...done
# read for  по Тюменской области https://www.reformagkh.ru/opendata/export/192...done
# read for  по Удмуртской Республике https://www.reformagkh.ru/opendata/export/230...done
# read for  по Ульяновской области https://www.reformagkh.ru/opendata/export/229...done
# read for  по Хабаровскому краю https://www.reformagkh.ru/opendata/export/247...done
# read for  по Ханты-Мансийскому автономному округу https://www.reformagkh.ru/opendata/export/189...done
# read for  по Челябинской области https://www.reformagkh.ru/opendata/export/188...done
# read for  по Чеченской Республике https://www.reformagkh.ru/opendata/export/206...done
# read for  по Чувашской Республике https://www.reformagkh.ru/opendata/export/176...done
# read for  по Чукотскому автономному округу https://www.reformagkh.ru/opendata/export/246...done
# read for  по Ямало-Ненецкому автономному округу https://www.reformagkh.ru/opendata/export/172...done
# read for  по Ярославской области https://www.reformagkh.ru/opendata/export/177...done

# %%
delete_temp_files()

# %%
pd_data=pd.read_csv(path.join(strDB_Temp, '172.zip'), sep=';')
pd_data
# Out:
#                            subject_rf  mun_obr_oktmo  \
# 0     Ямало-Ненецкий автономный округ       71952000
# 1     Ямало-Ненецкий автономный округ       71952000
# 2     Ямало-Ненецкий автономный округ       71952000
# 3     Ямало-Ненецкий автономный округ       71952000
# 4     Ямало-Ненецкий автономный округ       71952000
# ...                               ...            ...
# 2398  Ямало-Ненецкий автономный округ       71928000
# 2399  Ямало-Ненецкий автономный округ       71928000
# 2400  Ямало-Ненецкий автономный округ       71928000
# 2401  Ямало-Ненецкий автономный округ       71928000
# 2402  Ямало-Ненецкий автономный округ       71928000
#
#                             mun_obr    mkd_code  \
# 0                  город Губкинский  5200000203
# 1                  город Губкинский  5200000204
# 2                  город Губкинский  5200000208
# 3                  город Губкинский  5200000217
# 4                  город Губкинский  5200000223
# ...                             ...         ...
# 2398  Ямальский муниципальный район  2841760127
# 2399  Ямальский муниципальный район  2841760087
# 2400  Ямальский муниципальный район  2841760088
# 2401  Ямальский муниципальный район  2841760089
# 2402  Ямальский муниципальный район  2841760074
#
#                                  houseguid  \
# 0     e06d44a7-a40c-496b-a09a-a9b35a8b4974
# 1     7fe8679c-be8d-431a-b25e-10a6e606ab13
# 2     d83ea86b-5781-45c7-9058-fc5bdebf1452
# 3     ebbeedc0-e591-43fa-b14e-b6ee79adad28
# 4     175cc98d-e78d-476d-841b-666c29fdda44
# ...                                    ...
# 2398  d29901ce-4ba3-4f24-9296-eef54a87621d
# 2399  80ebe097-ceb5-48f0-a46d-96884ef3c2b1
# 2400  a6cb586d-4316-4902-863e-e69af6d4a980
# 2401  7c356fc1-14a4-4a0a-ae09-4311a1172c97
# 2402  61b2819f-4a8d-42fd-95b8-c0a33e361188
#
#                                   address  commission_year  \
# 0         г. Губкинский, мкр. 11-й, д. 34             1990
# 1         г. Губкинский, мкр. 11-й, д. 35             2004
# 2         г. Губкинский, мкр. 11-й, д. 39             2005
# 3         г. Губкинский, мкр. 11-й, д. 49             1994
# 4          г. Губкинский, мкр. 12-й, д. 1             1997
# ...                                   ...              ...
# 2398  с. Яр-Сале, ул. Худи Сэроко, д. 45А             2014
# 2399   с. Яр-Сале, ул. Худи Сэроко, д. 46             1988
# 2400   с. Яр-Сале, ул. Худи Сэроко, д. 48             2003
# 2401   с. Яр-Сале, ул. Худи Сэроко, д. 49             2009
# 2402    с. Яр-Сале, ул. Худи Сэроко, д. 9             1989
#
#       architectural_monument_status total_sq  total_rooms_amount  ...  \
# 0                               NaN   827,10                  12  ...
# 1                               NaN  2618,10                  18  ...
# 2                               NaN  2570,30                  62  ...
# 3                               NaN   809,10                  14  ...
# 4                               NaN  1609,00                  18  ...
# ...                             ...      ...                 ...  ...
# 2398                            NaN  1520,40                  28  ...
# 2399                            NaN   336,40                   8  ...
# 2400                            NaN   499,80                   6  ...
# 2401                            NaN   581,90                  11  ...
# 2402                            NaN   560,60                  12  ...
#
#       money_ppl_collected_date  owners_payment energy_efficiency  \
# 0                   01.10.2015           10,50       не присвоен
# 1                   01.10.2015           10,50       не присвоен
# 2                   01.10.2015           10,50       не присвоен
# 3                   01.10.2015           10,50       не присвоен
# 4                   01.10.2015           10,50       не присвоен
# ...                        ...             ...               ...
# 2398                01.07.2017           10,50       не присвоен
# 2399                01.10.2015           10,50       не присвоен
# 2400                01.10.2015           10,50       не присвоен
# 2401                01.10.2015           10,50       не присвоен
# 2402                01.10.2015           10,50       не присвоен
#
#      previous_energy_efficiency energy_audit_date  \
# 0                           NaN               NaN
# 1                           NaN               NaN
# 2                           NaN               NaN
# 3                           NaN               NaN
# 4                           NaN               NaN
# ...                         ...               ...
# 2398                        NaN               NaN
# 2399                        NaN               NaN
# 2400                        NaN               NaN
# 2401                        NaN               NaN
# 2402                        NaN               NaN
#
#       is_change_energy_efficiency exclude_date_from_program comment  \
# 0                             Нет                       NaN     NaN
# 1                             Нет                       NaN     NaN
# 2                             Нет                       NaN     NaN
# 3                             Нет                       NaN     NaN
# 4                             Нет                       NaN     NaN
# ...                           ...                       ...     ...
# 2398                          Нет                       NaN     NaN
# 2399                          Нет                22.01.2016     NaN
# 2400                          Нет                       NaN     NaN
# 2401                          Нет                       NaN     NaN
# 2402                          Нет                22.01.2016     NaN
#
#       last_update   house_id
# 0      10.06.2020  7754544.0
# 1      10.06.2020  7756726.0
# 2      10.06.2020  7756520.0
# 3      10.06.2020  7758341.0
# 4      10.06.2020  7759867.0
# ...           ...        ...
# 2398   10.06.2020  7546808.0
# 2399   10.06.2020  8454276.0
# 2400   10.06.2020  8606954.0
# 2401   10.06.2020  9015886.0
# 2402   10.06.2020  8453126.0
#
# [2403 rows x 35 columns]

# %%
dom_html=requests.get(strBaseDB_URL.format(page_num=1, page_size=100))
dsp=BeautifulSoup(dom_html.text, 'html.parser')
# Out:
# 5

# %%
p_caps=dsp.findAll('p', text=re.compile('Реестр домов по'))
div_p=p_caps[0].find_next('div', class_='row').find('a', href=re_a_export)
print(div_p['href'])
# Out:
# /opendata/export/118
