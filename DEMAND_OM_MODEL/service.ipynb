# %% [markdown]
# # Всякая сервисная ерунда

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
lstVarDB=['UZUss_x', 'MEPop', 'DispPop', 'price1mddy_alt_x', 'price1mall_alt_x', 'Pop_x', 'HHAv', 
          'Inc_x', 'p_ProbDef', 'CPIAv', 'Unmpl_s', 'p_superrich']
lstUGUDB=['sdelkikp_x', 'oldpravaddy_x', 'izavarijnogo', ]

lstVarsComm=['_comm_income', '_p_income_superr', '_superrich_buy', 'UZUss_s', 'LivMin', '_inc_percapita_superrich',  '_cnt_hh']

lstVars1=['_PDHouses_w',  '_p_self_improve', '_Calc_PD_FH_OM_Corr', '_PD', '_val_incom2house',
         '_val_m4h', '_sum_val_PM4dem_h_om', '_mid_level', '_part_income4h', 'p_middleclass', '_p_income4h', 
          'squareddy_ss_x']

lstVar2=['p_middleclass2', '_mid_level2', '_part_income4h2', '_calc_val_m4h2', '_spend_hh2', '_val_m4h2', '_sum_val_PM4dem_h_om2', 
         '_val_income2house2', '_demand_hh_m2', '_p_self_improve2', 
        '_demand_hh_calc', '_demand_hh', 'squarekp_ss_x']

lstVarUGU=['oldsdelkiddy_x', 'oldsdelkiddy_xM', ]

lst_e_UGU=[('oldsdelkiddy_x', 'oldpravaddy_x'), 
           ('oldsdelkiddy_x', 'sdelkikp_x'),
           ('oldsdelkiddy_xM', 'oldsdelkiddy_x'),
]

G=nx.DiGraph()
G.add_nodes_from(lstVarDB+lstVarsComm+lstVars1+lstVar2)
G.nodes.data()
# Out:
# NodeDataView({'UZUss_x': {}, 'MEPop': {}, 'DispPop': {}, 'price1mddy_alt_x': {}, 'price1mall_alt_x': {}, 'Pop_x': {}, 'HHAv': {}, 'Inc_x': {}, 'p_ProbDef': {}, 'CPIAv': {}, 'Unmpl_s': {}, 'p_superrich': {}, '_comm_income': {}, '_p_income_superr': {}, '_superrich_buy': {}, 'UZUss_s': {}, 'LivMin': {}, '_inc_percapita_superrich': {}, '_cnt_hh': {}, '_PDHouses_w': {}, '_p_self_improve': {}, '_Calc_PD_FH_OM_Corr': {}, '_PD': {}, '_val_incom2house': {}, '_val_m4h': {}, '_sum_val_PM4dem_h_om': {}, '_mid_level': {}, '_part_income4h': {}, 'p_middleclass': {}, '_p_income4h': {}, 'squareddy_ss_x': {}, 'p_middleclass2': {}, '_mid_level2': {}, '_part_income4h2': {}, '_calc_val_m4h2': {}, '_spend_hh2': {}, '_val_m4h2': {}, '_sum_val_PM4dem_h_om2': {}, '_val_income2house2': {}, '_demand_hh_m2': {}, '_p_self_improve2': {}, '_demand_hh_calc': {}, '_demand_hh': {}, 'squarekp_ss_x': {}})

# %%
lev0=['squareddy_ss_x', 'squarekp_ss_x']
lev1=['_PDHouses_w', 'Unmpl_s', '_demand_hh', '_demand_hh_calc']
lev2=['_Calc_PD_FH_OM_Corr', 'p_ProbDef', '_demand_hh_m2']
lev3=['_PD', '_superrich_buy', '_p_self_improve', '_p_self_improve2', '_val_income2house2']
lev4=['_val_incom2house', 'UZUss_s', '_val_m4h', '_calc_val_m4h2', '_val_m4h2', '_sum_val_PM4dem_h_om2']
lev5=['_p_income4h', '_cnt_hh', '_sum_val_PM4dem_h_om', '_comm_income', 'UZUss_x', '_spend_hh2']
lev6=['p_middleclass', '_p_income_superr', '_part_income4h', 'p_middleclass2', '_part_income4h2', '_mid_level2']
lev7=['_mid_level', 'Inc_x', '_inc_percapita_superrich', 'LivMin']
lev8=['price1mddy_alt_x', 'Unmpl_s', 'HHAv', 'Pop_x', 'price1mall_alt_x']
lev9=[ 'MEPop', 'DispPop', 'CPIAv', 'Unmpl_s', 'p_superrich']
list_level=[lev9, lev8, lev7, lev6, lev5, lev4, lev3, lev2, lev1, lev0]

for n in G.nodes:
    for i, v in enumerate(list_level):
        if n in v:
            G.nodes[n]['level']=i
for i in G.nodes.data():
    print(i[0], '\t\t\t', i[1])
# Out:
# UZUss_x 			 {'level': 4}
# MEPop 			 {'level': 0}
# DispPop 			 {'level': 0}
# price1mddy_alt_x 			 {'level': 1}
# price1mall_alt_x 			 {'level': 1}
# Pop_x 			 {'level': 1}
# HHAv 			 {'level': 1}
# Inc_x 			 {'level': 2}
# p_ProbDef 			 {'level': 7}
# CPIAv 			 {'level': 0}
# Unmpl_s 			 {'level': 8}
# p_superrich 			 {'level': 0}
# _comm_income 			 {'level': 4}
# _p_income_superr 			 {'level': 3}
# _superrich_buy 			 {'level': 6}
# UZUss_s 			 {'level': 5}
# LivMin 			 {'level': 2}
# _inc_percapita_superrich 			 {'level': 2}
# _cnt_hh 			 {'level': 4}
# _PDHouses_w 			 {'level': 8}
# _p_self_improve 			 {'level': 6}
# _Calc_PD_FH_OM_Corr 			 {'level': 7}
# _PD 			 {'level': 6}
# _val_incom2house 			 {'level': 5}
# _val_m4h 			 {'level': 5}
# _sum_val_PM4dem_h_om 			 {'level': 4}
# _mid_level 			 {'level': 2}
# _part_income4h 			 {'level': 3}
# p_middleclass 			 {'level': 3}
# _p_income4h 			 {'level': 4}
# squareddy_ss_x 			 {'level': 9}
# p_middleclass2 			 {'level': 3}
# ...

# %%
lst_e=[('_PDHouses_w', '_Calc_PD_FH_OM_Corr'), 
('_PDHouses_w', 'p_ProbDef'), 
('_PDHouses_w', 'price1mddy_alt_x'), 
('_PDHouses_w', 'price1mall_alt_x'), 
('_Calc_PD_FH_OM_Corr', '_PD'), 
('_Calc_PD_FH_OM_Corr', 'Pop_x'), 
('_Calc_PD_FH_OM_Corr', '_superrich_buy'), 
('_Calc_PD_FH_OM_Corr', 'p_superrich'), 
('_Calc_PD_FH_OM_Corr', '_p_self_improve'),
('_superrich_buy', 'HHAv'), 
('_PD', 'price1mddy_alt_x'), 
('_PD', '_val_incom2house'), 
('_val_incom2house', '_val_m4h'), 
('_val_incom2house', '_sum_val_PM4dem_h_om'),
('_val_m4h', '_comm_income'),
('_val_m4h', '_p_income4h'),
('_p_income4h', '_part_income4h'),
('_p_income4h', '_p_income_superr'),
('_comm_income', 'Inc_x'),       
('_comm_income', 'Pop_x'),  
('_part_income4h', '_mid_level'),
('_part_income4h', 'DispPop'),
('_part_income4h', 'MEPop'),
('_part_income4h', 'Inc_x'),
('LivMin', 'CPIAv'),
('_mid_level', 'LivMin'),
('_mid_level', 'HHAv'),
('_mid_level', 'price1mddy_alt_x'),
('p_middleclass', '_mid_level'),
('p_middleclass', 'MEPop'),
('p_middleclass', 'DispPop'),
('_inc_percapita_superrich', 'p_superrich'),
('_inc_percapita_superrich', 'MEPop'),
('_inc_percapita_superrich', 'DispPop'),
('_p_income_superr', '_inc_percapita_superrich'),
('_p_income_superr', 'DispPop'),
('_p_income_superr', 'MEPop'),
('_p_income_superr', 'Inc_x'),
('_cnt_hh', 'Pop_x'),
('_cnt_hh', 'HHAv'),
('UZUss_s', 'UZUss_x'),
('UZUss_s', '_cnt_hh'),
('_sum_val_PM4dem_h_om', 'LivMin'),
('_sum_val_PM4dem_h_om', 'p_middleclass'),
('_sum_val_PM4dem_h_om', 'Pop_x'),
('_p_self_improve', 'UZUss_s'),
('_p_self_improve', 'p_middleclass'),
('squareddy_ss_x', '_PDHouses_w'),
('squareddy_ss_x', 'Unmpl_s')
]

lst_e2=[('p_middleclass2', 'MEPop'), 
        ('p_middleclass2', 'DispPop'),
        ('p_middleclass2', '_mid_level2'),
        ('_mid_level2', 'LivMin'), 
        ('_mid_level2', 'HHAv'), 
        ('_mid_level2', 'price1mall_alt_x'), 
        ('_part_income4h2', '_mid_level2'), 
        ('_part_income4h2', 'DispPop'), 
        ('_part_income4h2', 'MEPop'), 
        ('_part_income4h2', 'Inc_x'), 
        ('_calc_val_m4h2', '_part_income4h2'), 
        ('_calc_val_m4h2', '_comm_income'), 
        ('_spend_hh2', '_part_income4h2'), 
        ('_spend_hh2', '_p_income_superr'), 
        ('_sum_val_PM4dem_h_om2', 'LivMin'), 
        ('_sum_val_PM4dem_h_om2', 'p_middleclass2'), 
        ('_sum_val_PM4dem_h_om2', 'Pop_x'), 
        ('_calc_val_m4h2', '_comm_income'), 
        ('_calc_val_m4h2', '_part_income4h2'), 
        ('_spend_hh2', '_part_income4h2'), 
        ('_spend_hh2', '_p_income_superr'), 
        ('_val_m4h2', '_comm_income'), 
        ('_val_m4h2', '_spend_hh2'), 
        ('_sum_val_PM4dem_h_om2', 'LivMin'), 
        ('_sum_val_PM4dem_h_om2', 'p_middleclass2'), 
        ('_sum_val_PM4dem_h_om2', 'Pop_x'), 
        ('_val_income2house2', '_val_m4h2'), 
        ('_val_income2house2', '_sum_val_PM4dem_h_om2'), 
        ('_demand_hh_m2', '_val_income2house2'), 
        ('_demand_hh_m2', 'price1mall_alt_x'), 
        ('_p_self_improve2', 'UZUss_s'), 
        ('_p_self_improve2', 'p_middleclass2'), 
        ('_demand_hh_calc', '_demand_hh_m2'), 
        ('_demand_hh_calc', 'p_superrich'), 
        ('_demand_hh_calc', '_superrich_buy'), 
        ('_demand_hh_calc', '_p_self_improve2'), 
        ('_demand_hh', '_demand_hh_calc'), 
        ('_demand_hh', 'p_ProbDef'), 
        ('_demand_hh', 'price1mddy_alt_x'), 
        ('_demand_hh', 'price1mall_alt_x'), 
        ('squarekp_ss_x', '_demand_hh'), 
        ('squarekp_ss_x', 'DispInc_I'), 
        ('squarekp_ss_x', 'Unmpl_s'), 
       ]

list_edges1=[(i[1], i[0]) for i in lst_e]
list_edges2=[(i[1], i[0]) for i in lst_e2]

list_edges1+=list_edges2

lst_e_db1=list(filter(lambda x: (x[0] in lstVarDB) & (x[1] in lstVars1),  list_edges1))
lst_e_db2=list(filter(lambda x: (x[0] in lstVarDB) & (x[1] in lstVar2),  list_edges1))
lst_e_dbc=list(filter(lambda x: (x[0] in lstVarDB) & (x[1] in lstVarsComm),  list_edges1))
lst_e_comm1=list(filter(lambda x: (x[0] in lstVarsComm) & (x[1] in lstVars1),  list_edges1))
lst_e_comm2=list(filter(lambda x: (x[0] in lstVarsComm) & (x[1] in lstVar2),  list_edges1))
lst_e_commC=list(filter(lambda x: (x[0] in lstVarsComm) & (x[1] in lstVarsComm),  list_edges1))
lst_e_mod1=list(filter(lambda x: x[0] in lstVars1,  list_edges1))
lst_e_mod2=list(filter(lambda x: x[0] in lstVar2,  list_edges1))

G.add_edges_from(lst_e_db1 + lst_e_db2 + lst_e_comm1 + lst_e_comm2 + lst_e_mod1 + lst_e_mod2+lst_e_commC)
G.edges
# Out:
# OutEdgeView([('MEPop', '_part_income4h'), ('MEPop', 'p_middleclass'), ('MEPop', 'p_middleclass2'), ('MEPop', '_part_income4h2'), ('DispPop', '_part_income4h'), ('DispPop', 'p_middleclass'), ('DispPop', 'p_middleclass2'), ('DispPop', '_part_income4h2'), ('price1mddy_alt_x', '_PDHouses_w'), ('price1mddy_alt_x', '_PD'), ('price1mddy_alt_x', '_mid_level'), ('price1mddy_alt_x', '_demand_hh'), ('price1mall_alt_x', '_PDHouses_w'), ('price1mall_alt_x', '_mid_level2'), ('price1mall_alt_x', '_demand_hh_m2'), ('price1mall_alt_x', '_demand_hh'), ('Pop_x', '_Calc_PD_FH_OM_Corr'), ('Pop_x', '_sum_val_PM4dem_h_om'), ('Pop_x', '_sum_val_PM4dem_h_om2'), ('HHAv', '_mid_level'), ('HHAv', '_mid_level2'), ('Inc_x', '_part_income4h'), ('Inc_x', '_part_income4h2'), ('p_ProbDef', '_PDHouses_w'), ('p_ProbDef', '_demand_hh'), ('Unmpl_s', 'squareddy_ss_x'), ('Unmpl_s', 'squarekp_ss_x'), ('p_superrich', '_Calc_PD_FH_OM_Corr'), ('p_superrich', '_demand_hh_calc'), ('_comm_income', '_val_m4h'), ('_comm_income', '_
# ...

# %%
plt.figure(figsize=(23,15))


pos = nx.multipartite_layout(G, subset_key='level', align='vertical')

options = {"node_size": 9700, "alpha": 0.4, 'node_shape':'8', 'edgecolors':'k'}

nx.draw_networkx_nodes(G, pos, nodelist=lstVarDB, node_color="r", **options)
nx.draw_networkx_nodes(G, pos, nodelist=lstVarsComm, node_color="g", **options)
nx.draw_networkx_nodes(G, pos, nodelist=lstVars1, node_color="b", **options)
nx.draw_networkx_nodes(G, pos, nodelist=lstVar2, node_color="#ffff99", **options)

labels = nx.draw_networkx_labels(G, pos=pos, font_size=8)

nx.draw_networkx_edges(G, pos, width=1.0, alpha=0.5, min_source_margin =48, min_target_margin =50, edgelist=lst_e_db1, edge_color='r')
nx.draw_networkx_edges(G, pos, width=1.0, alpha=0.5, min_source_margin =48, min_target_margin =50, edgelist=lst_e_db2, edge_color='r')
nx.draw_networkx_edges(G, pos, width=1.0, alpha=0.5, min_source_margin =48, min_target_margin =50, edgelist=lst_e_dbc, edge_color='r')
nx.draw_networkx_edges(G, pos, width=1.0, alpha=0.5, min_source_margin =48, min_target_margin =50, edgelist=lst_e_mod1, edge_color='b')
nx.draw_networkx_edges(G, pos, width=1.0, alpha=0.5, min_source_margin =48, min_target_margin =50, edgelist=lst_e_mod2, edge_color='#996633')
nx.draw_networkx_edges(G, pos, width=1.0, alpha=0.5, min_source_margin =48, min_target_margin =50, edgelist=lst_e_comm1, edge_color='g')
nx.draw_networkx_edges(G, pos, width=1.0, alpha=0.5, min_source_margin =48, min_target_margin =50, edgelist=lst_e_comm2, edge_color='g')
nx.draw_networkx_edges(G, pos, width=1.0, alpha=0.5, min_source_margin =48, min_target_margin =50, edgelist=lst_e_commC, edge_color='g')
# nx.draw(G, pos, node_size=9700, font_size=9, alpha=0.6, font_color='#000000', with_labels =True,
#               font_weight='bold', node_shape ='8', node_color ="#d7e0fc", linewidths=3)

plt.show()

# %%
G_mod1=G.subgraph(lstVarDB+lstVarsComm+lstVars1).copy()
# G_mod1.add_nodes_from(lstVarDB+lstVarsComm+lstVars1)
G_mod1.add_edges_from(lst_e_db1 + lst_e_comm1 + lst_e_mod1 + lst_e_commC + lst_e_dbc)

G_mod1.nodes.data()
# Out:
# NodeDataView({'UZUss_x': {'level': 4}, 'MEPop': {'level': 0}, 'DispPop': {'level': 0}, 'price1mddy_alt_x': {'level': 1}, 'price1mall_alt_x': {'level': 1}, 'Pop_x': {'level': 1}, 'HHAv': {'level': 1}, 'Inc_x': {'level': 2}, 'p_ProbDef': {'level': 7}, 'CPIAv': {'level': 0}, 'Unmpl_s': {'level': 8}, 'p_superrich': {'level': 0}, '_comm_income': {'level': 4}, '_p_income_superr': {'level': 3}, '_superrich_buy': {'level': 6}, 'UZUss_s': {'level': 5}, 'LivMin': {'level': 2}, '_inc_percapita_superrich': {'level': 2}, '_cnt_hh': {'level': 4}, '_PDHouses_w': {'level': 8}, '_p_self_improve': {'level': 6}, '_Calc_PD_FH_OM_Corr': {'level': 7}, '_PD': {'level': 6}, '_val_incom2house': {'level': 5}, '_val_m4h': {'level': 5}, '_sum_val_PM4dem_h_om': {'level': 4}, '_mid_level': {'level': 2}, '_part_income4h': {'level': 3}, 'p_middleclass': {'level': 3}, '_p_income4h': {'level': 4}, 'squareddy_ss_x': {'level': 9}})

# %%
plt.figure(figsize=(23,10))


pos = nx.multipartite_layout(G_mod1, subset_key='level', align='vertical')

nx.draw_networkx_nodes(G_mod1, pos, nodelist=lstVarDB, node_color="r", **options)
nx.draw_networkx_nodes(G_mod1, pos, nodelist=lstVarsComm, node_color="g", **options)
nx.draw_networkx_nodes(G_mod1, pos, nodelist=lstVars1, node_color="b", **options)

labels = nx.draw_networkx_labels(G_mod1, pos=pos, font_size=8)

nx.draw_networkx_edges(G_mod1, pos, width=1.0, alpha=0.5, min_source_margin =48, min_target_margin =50, edgelist=lst_e_db1, edge_color='r')
# nx.draw_networkx_edges(G_mod1, pos, width=1.0, alpha=0.5, min_source_margin =48, min_target_margin =50, edgelist=lst_e_db2, edge_color='r')
nx.draw_networkx_edges(G_mod1, pos, width=1.0, alpha=0.5, min_source_margin =48, min_target_margin =50, edgelist=lst_e_dbc, edge_color='r')
nx.draw_networkx_edges(G_mod1, pos, width=1.0, alpha=0.5, min_source_margin =48, min_target_margin =50, edgelist=lst_e_mod1, edge_color='b')
# nx.draw_networkx_edges(G, pos, width=1.0, alpha=0.5, min_source_margin =48, min_target_margin =50, edgelist=lst_e_mod2, edge_color='#996633')
nx.draw_networkx_edges(G_mod1, pos, width=1.0, alpha=0.5, min_source_margin =48, min_target_margin =50, edgelist=lst_e_comm1, edge_color='g')
# nx.draw_networkx_edges(G_mod1, pos, width=1.0, alpha=0.5, min_source_margin =48, min_target_margin =50, edgelist=lst_e_comm2, edge_color='g')
nx.draw_networkx_edges(G_mod1, pos, width=1.0, alpha=0.5, min_source_margin =48, min_target_margin =50, edgelist=lst_e_commC, edge_color='g')

# nx.draw(G_mod1, pos, node_size=9700, font_size=12, alpha=0.6, font_color='#000000', with_labels =True,
#                font_weight='bold', node_shape ='8', node_color ="#d7e0fc", linewidths=3)

plt.show();

# %%
G_mod2=G.subgraph(lstVarDB+lstVarsComm+lstVar2).copy()
# G_mod1.add_nodes_from(lstVarDB+lstVarsComm+lstVars1)
G_mod2.add_edges_from(lst_e_db2 + lst_e_comm2 + lst_e_mod2 + lst_e_commC + lst_e_dbc)

G_mod2.nodes.data()
# Out:
# NodeDataView({'UZUss_x': {'level': 4}, 'MEPop': {'level': 0}, 'DispPop': {'level': 0}, 'price1mddy_alt_x': {'level': 1}, 'price1mall_alt_x': {'level': 1}, 'Pop_x': {'level': 1}, 'HHAv': {'level': 1}, 'Inc_x': {'level': 2}, 'p_ProbDef': {'level': 7}, 'CPIAv': {'level': 0}, 'Unmpl_s': {'level': 8}, 'p_superrich': {'level': 0}, '_comm_income': {'level': 4}, '_p_income_superr': {'level': 3}, '_superrich_buy': {'level': 6}, 'UZUss_s': {'level': 5}, 'LivMin': {'level': 2}, '_inc_percapita_superrich': {'level': 2}, '_cnt_hh': {'level': 4}, 'p_middleclass2': {'level': 3}, '_mid_level2': {'level': 3}, '_part_income4h2': {'level': 3}, '_calc_val_m4h2': {'level': 5}, '_spend_hh2': {'level': 4}, '_val_m4h2': {'level': 5}, '_sum_val_PM4dem_h_om2': {'level': 5}, '_val_income2house2': {'level': 6}, '_demand_hh_m2': {'level': 7}, '_p_self_improve2': {'level': 6}, '_demand_hh_calc': {'level': 8}, '_demand_hh': {'level': 8}, 'squarekp_ss_x': {'level': 9}})

# %%
plt.figure(figsize=(23,10))


pos = nx.multipartite_layout(G_mod2, subset_key='level', align='vertical')

nx.draw_networkx_nodes(G_mod2, pos, nodelist=lstVarDB, node_color="r", **options)
nx.draw_networkx_nodes(G_mod2, pos, nodelist=lstVarsComm, node_color="g", **options)
nx.draw_networkx_nodes(G_mod2, pos, nodelist=lstVar2, node_color="#ffff99", **options)

labels = nx.draw_networkx_labels(G_mod2, pos=pos, font_size=8)

# nx.draw_networkx_edges(G_mod1, pos, width=1.0, alpha=0.5, min_source_margin =48, min_target_margin =50, edgelist=lst_e_db1, edge_color='r')
nx.draw_networkx_edges(G_mod2, pos, width=1.0, alpha=0.5, min_source_margin =48, min_target_margin =50, edgelist=lst_e_db2, edge_color='r')
nx.draw_networkx_edges(G_mod2, pos, width=1.0, alpha=0.5, min_source_margin =48, min_target_margin =50, edgelist=lst_e_dbc, edge_color='r')
# nx.draw_networkx_edges(G_mod2, pos, width=1.0, alpha=0.5, min_source_margin =48, min_target_margin =50, edgelist=lst_e_mod1, edge_color='b')
nx.draw_networkx_edges(G_mod2, pos, width=1.0, alpha=0.5, min_source_margin =48, min_target_margin =50, edgelist=lst_e_mod2, edge_color='#996633')
# nx.draw_networkx_edges(G_mod2, pos, width=1.0, alpha=0.5, min_source_margin =48, min_target_margin =50, edgelist=lst_e_comm1, edge_color='g')
nx.draw_networkx_edges(G_mod2, pos, width=1.0, alpha=0.5, min_source_margin =48, min_target_margin =50, edgelist=lst_e_comm2, edge_color='g')
nx.draw_networkx_edges(G_mod2, pos, width=1.0, alpha=0.5, min_source_margin =48, min_target_margin =50, edgelist=lst_e_commC, edge_color='g')

# nx.draw(G_mod1, pos, node_size=9700, font_size=12, alpha=0.6, font_color='#000000', with_labels =True,
#                font_weight='bold', node_shape ='8', node_color ="#d7e0fc", linewidths=3)

plt.show();
